# %%
#https://github.com/krishnaik06/Complete-Feature-Selection/blob/master/5%20-%20Chi%20Square%20For%20Feature%20Selection%201.ipynb

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df=df[['sex','embarked','alone','pclass','survived']]

# %%
df.head()
# Out:
#       sex embarked  alone  pclass  survived
# 0    male        S  False       3         0
# 1  female        C  False       1         1
# 2  female        S   True       3         1
# 3  female        S  False       1         1
# 4    male        S   True       3         0

# %%
##lable encoding
import numpy as np
df['sex']=np.where(df['sex']=="male",1,0)
df.head(10)
# Out:
#    sex embarked  alone  pclass  survived
# 0    1        S  False       3         0
# 1    0        C  False       1         1
# 2    0        S   True       3         1
# 3    0        S  False       1         1
# 4    1        S   True       3         0
# 5    1        Q   True       3         0
# 6    1        S   True       1         0
# 7    1        S  False       3         0
# 8    0        S  False       3         1
# 9    0        C  False       2         1

# %%
### Let's perform label encoding on sex column
import numpy as np
### let's perform label encoding on embarked
ordinal_label = {k: i for i, k in enumerate(df['embarked'].unique(), 0)}
df['embarked'] = df['embarked'].map(ordinal_label)
df.head()
# Out:
#    sex  embarked  alone  pclass  survived
# 0    1         0  False       3         0
# 1    0         1  False       1         1
# 2    0         0   True       3         1
# 3    0         0  False       1         1
# 4    1         0   True       3         0

# %%
### let's perform label encoding on alone
df['alone']=np.where(df['alone']==True,1,0)
df.head()
# Out:
#    sex  embarked  alone  pclass  survived
# 0    1         0      0       3         0
# 1    0         1      0       1         1
# 2    0         0      1       3         1
# 3    0         0      0       1         1
# 4    1         0      1       3         0

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, y_train,y_test=train_test_split(df[['sex','embarked','alone','pclass']],
                                              df['survived'],test_size=0.3,random_state=100)

# %%
#perform chisqare test
#chi square retrun two vale = fscore and pvale

# %%
from sklearn.feature_selection import chi2
f_p_values=chi2(X_train,y_train)

# %%
f_p_values
# Out:
# (array([65.67929505,  7.55053653, 10.88471585, 21.97994154]),
#  array([5.30603805e-16, 5.99922095e-03, 9.69610546e-04, 2.75514881e-06]))

# %%
# 1st is fvalue the more the better 2nd is pvalue the less it is the better
import pandas as pd

# %%
p_values=pd.Series(f_p_values[1])
p_values.index=X_train.columns
p_values.sort_index()
# Out:
# alone       9.696105e-04
# embarked    5.999221e-03
# pclass      2.755149e-06
# sex         5.306038e-16
# dtype: float64

# %%
##sex is the most important as when we compare to for result
